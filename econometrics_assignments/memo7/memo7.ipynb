# %%
import matplotlib
from matplotlib import pyplot as plt
import pandas as pd
import statsmodels.api as sm
import numpy as np

# %%
data = pd.read_json('merged_gen_data.json')

data
# Out:
#                 DATE_TIME  PLANT_ID_x     SOURCE_KEY_x    DC_POWER   AC_POWER  \
# 0     2020-05-15 00:00:00     4135001  1BY6WEcLGh8j5v7    0.000000   0.000000
# 1     2020-05-15 00:15:00     4135001  1BY6WEcLGh8j5v7    0.000000   0.000000
# 2     2020-05-15 00:30:00     4135001  1BY6WEcLGh8j5v7    0.000000   0.000000
# 3     2020-05-15 00:45:00     4135001  1BY6WEcLGh8j5v7    0.000000   0.000000
# 4     2020-05-15 01:00:00     4135001  1BY6WEcLGh8j5v7    0.000000   0.000000
# ...                   ...         ...              ...         ...        ...
# 68279 2020-06-17 17:45:00     4135001  zVJPv84UY57bAof  958.857143  93.142857
# 68280 2020-06-17 18:00:00     4135001  zVJPv84UY57bAof  603.000000  58.414286
# 68281 2020-06-17 18:15:00     4135001  zVJPv84UY57bAof  340.250000  32.862500
# 68282 2020-06-17 18:30:00     4135001  zVJPv84UY57bAof   77.714286   7.485714
# 68283 2020-06-17 18:45:00     4135001  zVJPv84UY57bAof    0.000000   0.000000
#
#        DAILY_YIELD  TOTAL_YIELD  PLANT_ID_y     SOURCE_KEY_y  \
# 0         0.000000  6259559.000     4135001  HmiyD2TTLFNqkNe
# 1         0.000000  6259559.000     4135001  HmiyD2TTLFNqkNe
# 2         0.000000  6259559.000     4135001  HmiyD2TTLFNqkNe
# 3         0.000000  6259559.000     4135001  HmiyD2TTLFNqkNe
# 4         0.000000  6259559.000     4135001  HmiyD2TTLFNqkNe
# ...            ...          ...         ...              ...
# 68279  5874.428571  7363236.429     4135001  HmiyD2TTLFNqkNe
# 68280  5892.000000  7363254.000     4135001  HmiyD2TTLFNqkNe
# 68281  5903.750000  7363265.750     4135001  HmiyD2TTLFNqkNe
# 68282  5909.142857  7363271.143     4135001  HmiyD2TTLFNqkNe
# 68283  5910.000000  7363272.000     4135001  HmiyD2TTLFNqkNe
#
#        AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# 0                25.184316           22.857507     0.000000
# 1                25.084589           22.761668     0.000000
# 2                24.935753           22.592306     0.000000
# 3                24.846130           22.360852     0.000000
# 4                24.621525           22.165423     0.000000
# ...                    ...                 ...          ...
# 68279            24.174170           25.950272     0.065259
# 68280            24.130349           25.080925     0.041940
# 68281            24.038157           24.068250     0.023446
# 68282            23.840239           22.968658     0.007007
# 68283            23.583049           22.460372     0.000039
#
# [68284 rows x 12 columns]

# %%
final_df = data.drop(columns=['DATE_TIME','PLANT_ID_x','PLANT_ID_y','SOURCE_KEY_y'])
final_df = final_df.rename(columns={'SOURCE_KEY_x': 'SOURCE_KEY'})
final_df
# Out:
#             SOURCE_KEY    DC_POWER   AC_POWER  DAILY_YIELD  TOTAL_YIELD  \
# 0      1BY6WEcLGh8j5v7    0.000000   0.000000     0.000000  6259559.000
# 1      1BY6WEcLGh8j5v7    0.000000   0.000000     0.000000  6259559.000
# 2      1BY6WEcLGh8j5v7    0.000000   0.000000     0.000000  6259559.000
# 3      1BY6WEcLGh8j5v7    0.000000   0.000000     0.000000  6259559.000
# 4      1BY6WEcLGh8j5v7    0.000000   0.000000     0.000000  6259559.000
# ...                ...         ...        ...          ...          ...
# 68279  zVJPv84UY57bAof  958.857143  93.142857  5874.428571  7363236.429
# 68280  zVJPv84UY57bAof  603.000000  58.414286  5892.000000  7363254.000
# 68281  zVJPv84UY57bAof  340.250000  32.862500  5903.750000  7363265.750
# 68282  zVJPv84UY57bAof   77.714286   7.485714  5909.142857  7363271.143
# 68283  zVJPv84UY57bAof    0.000000   0.000000  5910.000000  7363272.000
#
#        AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# 0                25.184316           22.857507     0.000000
# 1                25.084589           22.761668     0.000000
# 2                24.935753           22.592306     0.000000
# 3                24.846130           22.360852     0.000000
# 4                24.621525           22.165423     0.000000
# ...                    ...                 ...          ...
# 68279            24.174170           25.950272     0.065259
# 68280            24.130349           25.080925     0.041940
# 68281            24.038157           24.068250     0.023446
# 68282            23.840239           22.968658     0.007007
# 68283            23.583049           22.460372     0.000039
#
# [68284 rows x 8 columns]

# %%
#For this analysis, I will use one example inverter
example_df = final_df[final_df['SOURCE_KEY'] == "1BY6WEcLGh8j5v7"]

example_df
# Out:
#            SOURCE_KEY     DC_POWER    AC_POWER  DAILY_YIELD  TOTAL_YIELD  \
# 0     1BY6WEcLGh8j5v7     0.000000    0.000000     0.000000  6259559.000
# 1     1BY6WEcLGh8j5v7     0.000000    0.000000     0.000000  6259559.000
# 2     1BY6WEcLGh8j5v7     0.000000    0.000000     0.000000  6259559.000
# 3     1BY6WEcLGh8j5v7     0.000000    0.000000     0.000000  6259559.000
# 4     1BY6WEcLGh8j5v7     0.000000    0.000000     0.000000  6259559.000
# ...               ...          ...         ...          ...          ...
# 3099  1BY6WEcLGh8j5v7  6298.000000  617.037500  1329.375000  6481127.375
# 3100  1BY6WEcLGh8j5v7  6747.000000  660.842857  1488.714286  6481286.714
# 3101  1BY6WEcLGh8j5v7  6404.500000  627.412500  1657.750000  6481455.750
# 3102  1BY6WEcLGh8j5v7  6260.571429  613.085714  1787.857143  6481585.857
# 3103  1BY6WEcLGh8j5v7  7522.750000  736.525000  1985.750000  6481783.750
#
#       AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# 0               25.184316           22.857507     0.000000
# 1               25.084589           22.761668     0.000000
# 2               24.935753           22.592306     0.000000
# 3               24.846130           22.360852     0.000000
# 4               24.621525           22.165423     0.000000
# ...                   ...                 ...          ...
# 3099            25.957446           38.814911     0.454355
# 3100            26.182827           40.228129     0.501060
# 3101            26.470134           41.115753     0.464914
# 3102            26.236733           37.096722     0.450858
# 3103            26.771501           42.283028     0.564246
#
# [3104 rows x 8 columns]

# %%
#Targets
dc = example_df['DC_POWER']
ac = example_df['AC_POWER']
daily_yield = example_df['DAILY_YIELD']

#Vars
amb_temp = example_df[['AMBIENT_TEMPERATURE']]
mod_temp = example_df[['MODULE_TEMPERATURE']]
irrad = example_df[['IRRADIATION']]

dc.shape, ac.shape, daily_yield.shape, amb_temp.shape, mod_temp.shape, irrad.shape
# Out:
# ((3104,), (3104,), (3104,), (3104, 1), (3104, 1), (3104, 1))

# %%
targets = ['DC_POWER', 'AC_POWER', 'DAILY_YIELD']
variables = ['AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION']

fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 15), constrained_layout=True)
for row, target in enumerate(targets):
    for col, variable in enumerate(variables):
        axes[row, col].scatter(example_df[variable], example_df[target])
        axes[row, col].set_xlabel(variable)
        axes[row, col].set_ylabel(target)
        axes[row, col].set_title(f'{variable} vs. {target}')

plt.show()

# %%
#We will aggregate averages for DAILY_YIELD regressions to model linear relationships
avg_data = data[data['SOURCE_KEY_x'] == "1BY6WEcLGh8j5v7"]

avg_data['DATE'] = pd.to_datetime(avg_data['DATE_TIME']).dt.date

daily_averages = avg_data.groupby('DATE').agg({
    'AMBIENT_TEMPERATURE': 'mean',
    'MODULE_TEMPERATURE': 'mean',
    'IRRADIATION': 'mean',
    'DAILY_YIELD': 'mean'
}).reset_index()

daily_average = daily_averages.drop(columns='DATE')

daily_average
# Out:
# C:\Users\Jared\AppData\Local\Temp\ipykernel_31048\1571527162.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_data['DATE'] = pd.to_datetime(avg_data['DATE_TIME']).dt.date
#     AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION  DAILY_YIELD
# 0             27.430823           32.582964     0.204699  2641.120776
# 1             26.780538           31.858851     0.211951  3380.406047
# 2             26.686727           32.740435     0.238869  3473.035714
# 3             23.850938           27.814344     0.159026  2271.423549
# 4             25.338021           29.725163     0.194031  3087.064900
# 5             25.150683           29.783704     0.240073  3155.774279
# 6             27.941912           37.964812     0.362403  5266.323535
# 7             26.526703           32.478885     0.230408  3356.129650
# 8             26.895118           34.956976     0.293333  4073.705123
# 9             27.625116           33.978544     0.259762  3702.991443
# 10            27.347039           34.969323     0.292658  4189.156298
# 11            26.881417           33.528988     0.255011  1922.678195
# 12            26.835469           32.420288     0.213933  3078.338728
# 13            27.136629           34.381938     0.289249  3674.762302
# 14            27.030236           38.143494     0.349235  4943.109457
# 15            24.991223           30.816012     0.227865  3138.490699
# 16            25.472600           30.160713     0.183599  2932.877790
# 17            24.779514           28.961083     0.183846  2885.799541
# 18            24.374920           29.448151     0.223788  3438.960007
# 19            24.795672           29.998063     0.230818  3457.684023
# 20            25.286176           31.221625     0.256989  3611.024182
# 21            24.870622           30.582565     0.241590  3413.161086
# 22            24.247355           28.802772     0.203405  3037.495350
# 23            25.016090           31.497892     0.254191  2617.497954
# 24            25.441268           31.621923     0.263703  3821.459449
# 25            25.545736           31.515744     0.257861  3643.422433
# 26            24.752468           29.202542     0.200336  2920.447247
# 27            24.403410           27.880257     0.161809  2464.198847
# 28            24.072379           27.585834     0.169808  2597.526786
# 29            24.566729           30.481026     0.264472  3927.478237
# 30            24.412891           29.421707     0.220086  2024.438058
# 31            24.827414           29.927817     0.205925  3164.440104
# 32            24.928929           29.555567     0.187283  2917.718378
# 33            23.482761           26.840178     0.141574   353.449269

# %%
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 15), constrained_layout=True)
for row, target in enumerate(targets + ['DAILY_YIELD']):  # Adding DAILY_YIELD for the last row
    for col, variable in enumerate(variables):
        if target in ['DC_POWER', 'AC_POWER']:  # Use original dataset for the first two rows
            axes[row, col].scatter(example_df[variable], example_df[target])
        else:  # Use daily averages for the last row
            axes[row, col].scatter(daily_averages[variable], daily_averages['DAILY_YIELD'])
        axes[row, col].set_xlabel(variable)
        axes[row, col].set_ylabel(target)
        axes[row, col].set_title(f'{variable} vs. {target}')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 7
#       5     axes[row, col].scatter(example_df[variable], example_df[target])
#       6 else:  # Use daily averages for the last row
# ----> 7     axes[row, col].scatter(daily_averages[variable], daily_averages['DAILY_YIELD'])
#       8 axes[row, col].set_xlabel(variable)
#       9 axes[row, col].set_ylabel(target)
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %%
def ols(x,y):
    x_constant = sm.add_constant(x)
    model = sm.OLS(y,x_constant)
    result = model.fit()
    return result.summary()

summaries = {}

for target in ['DC_POWER', 'AC_POWER']:
    for var in variables:
        key = f'{var} vs. {target}'
        summaries[key] = ols(example_df[[var]], example_df[target])

for var in variables:
    key = f'{var} vs. DAILY_YIELD'
    summaries[key] = ols(daily_average[[var]], daily_average['DAILY_YIELD'])

for summary in summaries:
    print(summaries[summary])
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               DC_POWER   R-squared:                       0.510
# Model:                            OLS   Adj. R-squared:                  0.510
# Method:                 Least Squares   F-statistic:                     3229.
# Date:                Mon, 08 Apr 2024   Prob (F-statistic):               0.00
# Time:                        12:32:32   Log-Likelihood:                -28851.
# No. Observations:                3104   AIC:                         5.771e+04
# Df Residuals:                    3102   BIC:                         5.772e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const               -1.756e+04    362.710    -48.409      0.000   -1.83e+04   -1.68e+04
# AMBIENT_TEMPERATURE   799.1071     14.064     56.820      0.000     771.532     826.682
# ==============================================================================
# Omnibus:                       33.423   Durbin-Watson:                   0.189
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.367
# Skew:                           0.228   Prob(JB):                     2.09e-08
# Kurtosis:                       3.257   Cond. No.                         198.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               DC_POWER   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.882
# Method:                 Least Squares   F-statistic:                 2.323e+04
# Date:                Mon, 08 Apr 2024   Prob (F-statistic):               0.00
# Time:                        12:32:32   Log-Likelihood:                -26639.
# No. Observations:                3104   AIC:                         5.328e+04
# Df Residuals:                    3102   BIC:                         5.329e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const              -6087.1524     63.212    -96.298      0.000   -6211.093   -5963.212
# MODULE_TEMPERATURE   287.2332      1.885    152.398      0.000     283.538     290.929
# ==============================================================================
# Omnibus:                     1370.300   Durbin-Watson:                   0.644
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22780.583
# Skew:                          -1.662   Prob(JB):                         0.00
# Kurtosis:                      15.849   Cond. No.                         91.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               DC_POWER   R-squared:                       0.936
# Model:                            OLS   Adj. R-squared:                  0.936
# Method:                 Least Squares   F-statistic:                 4.549e+04
# Date:                Mon, 08 Apr 2024   Prob (F-statistic):               0.00
# Time:                        12:32:32   Log-Likelihood:                -25688.
# No. Observations:                3104   AIC:                         5.138e+04
# Df Residuals:                    3102   BIC:                         5.139e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          91.8061     21.480      4.274      0.000      49.689     133.923
# IRRADIATION  1.207e+04     56.595    213.290      0.000     1.2e+04    1.22e+04
# ==============================================================================
# Omnibus:                     3958.666   Durbin-Watson:                   0.616
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           887784.004
# Skew:                          -6.839   Prob(JB):                         0.00
# Kurtosis:                      84.714   Cond. No.                         3.51
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               AC_POWER   R-squared:                       0.510
# Model:                            OLS   Adj. R-squared:                  0.510
# Method:                 Least Squares   F-statistic:                     3232.
# Date:                Mon, 08 Apr 2024   Prob (F-statistic):               0.00
# Time:                        12:32:32   Log-Likelihood:                -21632.
# No. Observations:                3104   AIC:                         4.327e+04
# Df Residuals:                    3102   BIC:                         4.328e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const               -1716.6473     35.444    -48.433      0.000   -1786.143   -1647.152
# AMBIENT_TEMPERATURE    78.1337      1.374     56.853      0.000      75.439      80.828
# ==============================================================================
# Omnibus:                       31.972   Durbin-Watson:                   0.188
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               33.701
# Skew:                           0.223   Prob(JB):                     4.81e-08
# Kurtosis:                       3.248   Cond. No.                         198.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               AC_POWER   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.882
# Method:                 Least Squares   F-statistic:                 2.327e+04
# Date:                Mon, 08 Apr 2024   Prob (F-statistic):               0.00
# Time:                        12:32:32   Log-Likelihood:                -19418.
# No. Observations:                3104   AIC:                         3.884e+04
# Df Residuals:                    3102   BIC:                         3.885e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               -594.8866      6.173    -96.363      0.000    -606.991    -582.782
# MODULE_TEMPERATURE    28.0798      0.184    152.550      0.000      27.719      28.441
# ==============================================================================
# Omnibus:                     1375.924   Durbin-Watson:                   0.641
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22931.218
# Skew:                          -1.670   Prob(JB):                         0.00
# Kurtosis:                      15.890   Cond. No.                         91.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               AC_POWER   R-squared:                       0.936
# Model:                            OLS   Adj. R-squared:                  0.936
# Method:                 Least Squares   F-statistic:                 4.545e+04
# Date:                Mon, 08 Apr 2024   Prob (F-statistic):               0.00
# Time:                        12:32:32   Log-Likelihood:                -18471.
# No. Observations:                3104   AIC:                         3.695e+04
# Df Residuals:                    3102   BIC:                         3.696e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           9.2067      2.101      4.383      0.000       5.088      13.325
# IRRADIATION  1179.8948      5.535    213.188      0.000    1169.043    1190.746
# ==============================================================================
# Omnibus:                     3958.026   Durbin-Watson:                   0.613
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           885218.593
# Skew:                          -6.838   Prob(JB):                         0.00
# Kurtosis:                      84.593   Cond. No.                         3.51
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            DAILY_YIELD   R-squared:                       0.328
# Model:                            OLS   Adj. R-squared:                  0.307
# Method:                 Least Squares   F-statistic:                     15.61
# Date:                Mon, 08 Apr 2024   Prob (F-statistic):           0.000402
# Time:                        12:32:32   Log-Likelihood:                -271.15
# No. Observations:                  34   AIC:                             546.3
# Df Residuals:                      32   BIC:                             549.4
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const               -7115.8347   2612.647     -2.724      0.010   -1.24e+04   -1794.047
# AMBIENT_TEMPERATURE   403.0260    102.020      3.950      0.000     195.218     610.834
# ==============================================================================
# Omnibus:                        8.302   Durbin-Watson:                   1.543
# Prob(Omnibus):                  0.016   Jarque-Bera (JB):                6.914
# Skew:                          -0.907   Prob(JB):                       0.0315
# Kurtosis:                       4.262   Cond. No.                         539.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            DAILY_YIELD   R-squared:                       0.532
# Model:                            OLS   Adj. R-squared:                  0.517
# Method:                 Least Squares   F-statistic:                     36.34
# Date:                Mon, 08 Apr 2024   Prob (F-statistic):           1.00e-06
# Time:                        12:32:32   Log-Likelihood:                -265.00
# No. Observations:                  34   AIC:                             534.0
# Df Residuals:                      32   BIC:                             537.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const              -4148.7500   1222.483     -3.394      0.002   -6638.866   -1658.634
# MODULE_TEMPERATURE   234.8789     38.965      6.028      0.000     155.509     314.249
# ==============================================================================
# Omnibus:                       19.740   Durbin-Watson:                   1.555
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.115
# Skew:                          -1.625   Prob(JB):                     2.13e-06
# Kurtosis:                       5.806   Cond. No.                         370.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            DAILY_YIELD   R-squared:                       0.653
# Model:                            OLS   Adj. R-squared:                  0.643
# Method:                 Least Squares   F-statistic:                     60.34
# Date:                Mon, 08 Apr 2024   Prob (F-statistic):           7.37e-09
# Time:                        12:32:32   Log-Likelihood:                -259.89
# No. Observations:                  34   AIC:                             523.8
# Df Residuals:                      32   BIC:                             526.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         -88.8327    431.888     -0.206      0.838    -968.559     790.893
# IRRADIATION  1.417e+04   1824.699      7.768      0.000    1.05e+04    1.79e+04
# ==============================================================================
# Omnibus:                       26.474   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.661
# Skew:                          -2.094   Prob(JB):                     5.45e-10
# Kurtosis:                       6.546   Cond. No.                         21.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
models = []
models_daily_yield = []
fig, axes = plt.subplots(len(targets), len(variables), figsize=(15, 10), constrained_layout=True)

for i, target in enumerate(targets + ['DAILY_YIELD']):  
    for j, variable in enumerate(variables):
        if target in ['DC_POWER', 'AC_POWER']: 
            X = example_df[[variable]]
            y = example_df[target]
        else:  
            X = daily_averages[[variable]]
            y = daily_averages['DAILY_YIELD']
            
        X_constant = sm.add_constant(X)
        
       
        model = sm.OLS(y, X_constant).fit()
        if target == 'DAILY_YIELD':
            models_daily_yield.append(model)  
        
   
        x_range = pd.DataFrame({variable: np.linspace(X[variable].min(), X[variable].max(), 100)})
        x_range_constant = sm.add_constant(x_range)
        predictions = model.predict(x_range_constant)
        
       
        axes[i, j].scatter(X[variable], y, alpha=0.5)
        
        
        axes[i, j].plot(x_range, predictions, color='red', linewidth=2)
        
        axes[i, j].set_title(f'{variable} vs. {target}')
        axes[i, j].set_xlabel(variable)
        axes[i, j].set_ylabel(target)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[23], line 27
#      23 x_range_constant = sm.add_constant(x_range)
#      24 predictions = model.predict(x_range_constant)
# ---> 27 axes[i, j].scatter(X[variable], y, alpha=0.5)
#      30 axes[i, j].plot(x_range, predictions, color='red', linewidth=2)
#      32 axes[i, j].set_title(f'{variable} vs. {target}')
#
# IndexError: index 3 is out of bounds for axis 0 with size 3
