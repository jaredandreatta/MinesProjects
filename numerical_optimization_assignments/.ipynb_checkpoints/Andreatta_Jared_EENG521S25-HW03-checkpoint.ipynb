# %%
import scipy
from scipy.optimize import minimize, line_search, rosen, rosen_der, rosen_hess
from scipy.linalg import qr
from matplotlib import pyplot as plt
import numpy as np
import import_ipynb
from EENG521S25_Quad_ndim_Setup import generate_lam, generate_lam_clustered, feval_cvx_quadratic, grad_cvx_quadratic, hess_cvx_quadratic
import warnings 
warnings.filterwarnings('ignore')

# %%
# Set up
np.random.seed(12345)
#  Generate A with n eigenvalues between m and L
n = 100
m = 10
L = 100
lam = generate_lam(n,m,L)
U = np.random.randn(n,n)
U, _ = qr(U) # generate a random orthogonal matrix by performing QR decomposition on a random Gaussian matrix
A = U@np.diag(lam)@U.T

# Generate A with n eigenvalues between m and L, occurring in q clusters
n = 100
m = 10
L = 100
q = 5   # Number of distinct values among the n eigenvalues
lam = generate_lam_clustered(n, q, m, L)
U = np.random.randn(n,n)
U, _ = qr(U) # generate a random orthogonal matrix by performing QR decomposition on a random Gaussian matrix
A = U@np.diag(lam)@U.T


# Try random points for initializing the algorithms
x0 = np.random.randn(n)

# %% [markdown]
# # Gradient Descent
#
# #### Comparing set step sizes
# Here, we will use different values of $m$ and $L$ to demonstrate that $\alpha_1 = \frac{1}{L}$ converges slower than $\alpha_2 = \frac{2}{m+L}$. I set the function to return the number of iterations that the algorithm converges in. I then set up an if statement to print if $alpha_2$ yielded better convergence rates. I find that this is true for all $m$ and $L$ that I tested.

# %%
# Gradient Descent 
def gradient_descent(A, x0, alpha, max_iters=10000, tol=1e-8):
    x = x0.copy()
    errors = []
    for i in range(max_iters):
        error = np.linalg.norm(x)
        errors.append(error)
        if error < tol:
            break
        x = x - alpha * grad_cvx_quadratic(x, A)
    return i
    

for m in range(1, 11):
    for L in range(10, 110, 10):
        q = 5   # Number of distinct values among the n eigenvalues
        lam = generate_lam_clustered(n, q, m, L)
        U = np.random.randn(n,n)
        U, _ = qr(U) # generate a random orthogonal matrix by performing QR decomposition on a random Gaussian matrix
        A = U@np.diag(lam)@U.T
        
        # Using predefined step sizes
        alpha_1 = 1.0 / L
        alpha_2 = 2.0 / (m + L)

        # If alpha_2 converges in less iterations than alpha_1 given m and L, then this prints that 
        if gradient_descent(A, x0, alpha_1) > gradient_descent(A, x0, alpha_2):
            print(f"m={m}, L={L}, alpha_2 ({gradient_descent(A, x0, alpha_2)} iterations) converges faster than alpha_1 ({gradient_descent(A, x0, alpha_1)} iterations)")
# Out:
# m=1, L=10, alpha_2 (95 iterations) converges faster than alpha_1 (180 iterations)
# m=1, L=20, alpha_2 (190 iterations) converges faster than alpha_1 (349 iterations)
# m=1, L=30, alpha_2 (285 iterations) converges faster than alpha_1 (547 iterations)
# m=1, L=40, alpha_2 (378 iterations) converges faster than alpha_1 (663 iterations)
# m=1, L=50, alpha_2 (488 iterations) converges faster than alpha_1 (959 iterations)
# m=1, L=60, alpha_2 (558 iterations) converges faster than alpha_1 (1022 iterations)
# m=1, L=70, alpha_2 (539 iterations) converges faster than alpha_1 (1057 iterations)
# m=1, L=80, alpha_2 (755 iterations) converges faster than alpha_1 (1482 iterations)
# m=1, L=90, alpha_2 (852 iterations) converges faster than alpha_1 (1694 iterations)
# m=1, L=100, alpha_2 (916 iterations) converges faster than alpha_1 (1805 iterations)
# m=2, L=10, alpha_2 (43 iterations) converges faster than alpha_1 (76 iterations)
# m=2, L=20, alpha_2 (92 iterations) converges faster than alpha_1 (172 iterations)
# m=2, L=30, alpha_2 (131 iterations) converges faster than alpha_1 (248 iterations)
# m=2, L=40, alpha_2 (185 iterations) converges faster than alpha_1 (355 iterations)
# m=2, L=50, alpha_2 (237 iterations) converges faster than alpha_1 (465 iterations)
# m=2, L=60, alpha_2 (291 iterations) converges faster than alpha_1 (572 iterations)
# m=2, L=70, alpha_2 (328 iterations) converges faster than alpha_1 (615 iterations)
# m=2, L=80, alpha_2 (375 iterations) converges faster than alpha_1 (718 iterations)
# m=2, L=90, alpha_2 (435 iterations) converges faster than alpha_1 (858 iterations)
# m=2, L=100, alpha_2 (479 iterations) converges faster than alpha_1 (948 iterations)
# m=3, L=10, alpha_2 (31 iterations) converges faster than alpha_1 (53 iterations)
# m=3, L=20, alpha_2 (62 iterations) converges faster than alpha_1 (99 iterations)
# m=3, L=30, alpha_2 (93 iterations) converges faster than alpha_1 (177 iterations)
# m=3, L=40, alpha_2 (122 iterations) converges faster than alpha_1 (214 iterations)
# m=3, L=50, alpha_2 (150 iterations) converges faster than alpha_1 (291 iterations)
# m=3, L=60, alpha_2 (185 iterations) converges faster than alpha_1 (353 iterations)
# m=3, L=70, alpha_2 (221 iterations) converges faster than alpha_1 (421 iterations)
# m=3, L=80, alpha_2 (253 iterations) converges faster than alpha_1 (464 iterations)
# m=3, L=90, alpha_2 (263 iterations) converges faster than alpha_1 (515 iterations)
# m=3, L=100, alpha_2 (310 iterations) converges faster than alpha_1 (539 iterations)
# m=4, L=10, alpha_2 (23 iterations) converges faster than alpha_1 (35 iterations)
# m=4, L=20, alpha_2 (45 iterations) converges faster than alpha_1 (80 iterations)
# m=4, L=30, alpha_2 (68 iterations) converges faster than alpha_1 (124 iterations)
# m=4, L=40, alpha_2 (90 iterations) converges faster than alpha_1 (164 iterations)
# m=4, L=50, alpha_2 (118 iterations) converges faster than alpha_1 (227 iterations)
# m=4, L=60, alpha_2 (139 iterations) converges faster than alpha_1 (252 iterations)
# m=4, L=70, alpha_2 (169 iterations) converges faster than alpha_1 (323 iterations)
# m=4, L=80, alpha_2 (185 iterations) converges faster than alpha_1 (350 iterations)
# m=4, L=90, alpha_2 (214 iterations) converges faster than alpha_1 (398 iterations)
# m=4, L=100, alpha_2 (239 iterations) converges faster than alpha_1 (457 iterations)
# m=5, L=10, alpha_2 (18 iterations) converges faster than alpha_1 (27 iterations)
# m=5, L=20, alpha_2 (37 iterations) converges faster than alpha_1 (65 iterations)
# m=5, L=30, alpha_2 (57 iterations) converges faster than alpha_1 (104 iterations)
# m=5, L=40, alpha_2 (75 iterations) converges faster than alpha_1 (141 iterations)
# m=5, L=50, alpha_2 (94 iterations) converges faster than alpha_1 (160 iterations)
# m=5, L=60, alpha_2 (109 iterations) converges faster than alpha_1 (209 iterations)
# m=5, L=70, alpha_2 (126 iterations) converges faster than alpha_1 (223 iterations)
# m=5, L=80, alpha_2 (151 iterations) converges faster than alpha_1 (288 iterations)
# m=5, L=90, alpha_2 (165 iterations) converges faster than alpha_1 (321 iterations)
# m=5, L=100, alpha_2 (188 iterations) converges faster than alpha_1 (366 iterations)
# m=6, L=10, alpha_2 (14 iterations) converges faster than alpha_1 (20 iterations)
# m=6, L=20, alpha_2 (31 iterations) converges faster than alpha_1 (51 iterations)
# m=6, L=30, alpha_2 (45 iterations) converges faster than alpha_1 (59 iterations)
# m=6, L=40, alpha_2 (63 iterations) converges faster than alpha_1 (118 iterations)
# m=6, L=50, alpha_2 (79 iterations) converges faster than alpha_1 (147 iterations)
# m=6, L=60, alpha_2 (89 iterations) converges faster than alpha_1 (163 iterations)
# m=6, L=70, alpha_2 (112 iterations) converges faster than alpha_1 (213 iterations)
# m=6, L=80, alpha_2 (125 iterations) converges faster than alpha_1 (238 iterations)
# m=6, L=90, alpha_2 (141 iterations) converges faster than alpha_1 (269 iterations)
# m=6, L=100, alpha_2 (158 iterations) converges faster than alpha_1 (281 iterations)
# m=7, L=10, alpha_2 (12 iterations) converges faster than alpha_1 (16 iterations)
# m=7, L=20, alpha_2 (25 iterations) converges faster than alpha_1 (33 iterations)
# m=7, L=30, alpha_2 (38 iterations) converges faster than alpha_1 (67 iterations)
# m=7, L=40, alpha_2 (54 iterations) converges faster than alpha_1 (84 iterations)
# m=7, L=50, alpha_2 (65 iterations) converges faster than alpha_1 (109 iterations)
# m=7, L=60, alpha_2 (78 iterations) converges faster than alpha_1 (147 iterations)
# m=7, L=70, alpha_2 (88 iterations) converges faster than alpha_1 (166 iterations)
# m=7, L=80, alpha_2 (103 iterations) converges faster than alpha_1 (198 iterations)
# m=7, L=90, alpha_2 (115 iterations) converges faster than alpha_1 (220 iterations)
# m=7, L=100, alpha_2 (133 iterations) converges faster than alpha_1 (256 iterations)
# m=8, L=10, alpha_2 (9 iterations) converges faster than alpha_1 (12 iterations)
# m=8, L=20, alpha_2 (22 iterations) converges faster than alpha_1 (35 iterations)
# m=8, L=30, alpha_2 (35 iterations) converges faster than alpha_1 (61 iterations)
# m=8, L=40, alpha_2 (47 iterations) converges faster than alpha_1 (77 iterations)
# m=8, L=50, alpha_2 (56 iterations) converges faster than alpha_1 (103 iterations)
# m=8, L=60, alpha_2 (72 iterations) converges faster than alpha_1 (134 iterations)
# m=8, L=70, alpha_2 (82 iterations) converges faster than alpha_1 (144 iterations)
# m=8, L=80, alpha_2 (93 iterations) converges faster than alpha_1 (174 iterations)
# m=8, L=90, alpha_2 (102 iterations) converges faster than alpha_1 (175 iterations)
# m=8, L=100, alpha_2 (112 iterations) converges faster than alpha_1 (213 iterations)
# m=9, L=10, alpha_2 (7 iterations) converges faster than alpha_1 (8 iterations)
# m=9, L=20, alpha_2 (19 iterations) converges faster than alpha_1 (30 iterations)
# m=9, L=30, alpha_2 (30 iterations) converges faster than alpha_1 (50 iterations)
# m=9, L=40, alpha_2 (40 iterations) converges faster than alpha_1 (58 iterations)
# m=9, L=50, alpha_2 (50 iterations) converges faster than alpha_1 (90 iterations)
# m=9, L=60, alpha_2 (60 iterations) converges faster than alpha_1 (99 iterations)
# m=9, L=70, alpha_2 (74 iterations) converges faster than alpha_1 (133 iterations)
# m=9, L=80, alpha_2 (84 iterations) converges faster than alpha_1 (142 iterations)
# m=9, L=90, alpha_2 (82 iterations) converges faster than alpha_1 (153 iterations)
# m=9, L=100, alpha_2 (101 iterations) converges faster than alpha_1 (175 iterations)
# m=10, L=20, alpha_2 (16 iterations) converges faster than alpha_1 (26 iterations)
# m=10, L=30, alpha_2 (28 iterations) converges faster than alpha_1 (44 iterations)
# m=10, L=40, alpha_2 (37 iterations) converges faster than alpha_1 (57 iterations)
# m=10, L=50, alpha_2 (45 iterations) converges faster than alpha_1 (66 iterations)
# m=10, L=60, alpha_2 (55 iterations) converges faster than alpha_1 (101 iterations)
# m=10, L=70, alpha_2 (67 iterations) converges faster than alpha_1 (124 iterations)
# m=10, L=80, alpha_2 (70 iterations) converges faster than alpha_1 (131 iterations)
# m=10, L=90, alpha_2 (86 iterations) converges faster than alpha_1 (156 iterations)
# m=10, L=100, alpha_2 (93 iterations) converges faster than alpha_1 (170 iterations)

# %% [markdown]
# #### Comparing with Line Search step sizes
# I repeated the same process by comparing $\alpha_2 = \frac{2}{m+L}$ to the $\alpha$ found by the line search algorithm. Clearly, it outperforms the fixed step size.

# %%
# Gradient Descent with Line Search
def gradient_descent_line_search(A, x0, max_iters=10000, tol=1e-8):
    x = x0.copy()
    errors = []
    for i in range(max_iters):
        error = np.linalg.norm(x)
        errors.append(error)
        if error < tol:
            break
        # Function and gradient of the objective function
        f = lambda x_val: feval_cvx_quadratic(x_val, A)
        grad_f = lambda x_val: grad_cvx_quadratic(x_val, A)
        
        # Perform Wolfe line search to determine step size
        ls = line_search(f, grad_f, x, -grad_f(x))
        alpha = ls[0]
        if alpha is None:
            # If line search does not converge
            alpha = 1e-3
        x = x - alpha * grad_f(x)
    return i

for m in range(1, 11):
    for L in range(10, 110, 10):
        q = 5   # Number of distinct values among the n eigenvalues
        lam = generate_lam_clustered(n, q, m, L)
        U = np.random.randn(n,n)
        U, _ = qr(U) # generate a random orthogonal matrix by performing QR decomposition on a random Gaussian matrix
        A =  A = U@np.diag(lam)@U.T
        
        # Using predefined step sizes
        alpha_2 = 2.0 / (m + L)

        print(f"m={m}, L={L}, alpha_2 ({gradient_descent_line_search(A, x0)} iterations) converges faster than alpha_2 ({gradient_descent(A, x0, alpha_2)} iterations)")
# Out:
# m=1, L=10, alpha_2 (89 iterations) converges faster than alpha_2 (91 iterations)
# m=1, L=20, alpha_2 (113 iterations) converges faster than alpha_2 (181 iterations)
# m=1, L=30, alpha_2 (49 iterations) converges faster than alpha_2 (277 iterations)
# m=1, L=40, alpha_2 (233 iterations) converges faster than alpha_2 (387 iterations)
# m=1, L=50, alpha_2 (115 iterations) converges faster than alpha_2 (468 iterations)
# m=1, L=60, alpha_2 (26 iterations) converges faster than alpha_2 (579 iterations)
# m=1, L=70, alpha_2 (270 iterations) converges faster than alpha_2 (651 iterations)
# m=1, L=80, alpha_2 (274 iterations) converges faster than alpha_2 (696 iterations)
# m=1, L=90, alpha_2 (135 iterations) converges faster than alpha_2 (835 iterations)
# /Users/jayco/anaconda3/lib/python3.11/site-packages/scipy/optimize/_linesearch.py:314: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# m=1, L=100, alpha_2 (609 iterations) converges faster than alpha_2 (958 iterations)
# m=2, L=10, alpha_2 (44 iterations) converges faster than alpha_2 (46 iterations)
# m=2, L=20, alpha_2 (64 iterations) converges faster than alpha_2 (87 iterations)
# m=2, L=30, alpha_2 (70 iterations) converges faster than alpha_2 (133 iterations)
# m=2, L=40, alpha_2 (60 iterations) converges faster than alpha_2 (191 iterations)
# m=2, L=50, alpha_2 (80 iterations) converges faster than alpha_2 (219 iterations)
# m=2, L=60, alpha_2 (165 iterations) converges faster than alpha_2 (277 iterations)
# m=2, L=70, alpha_2 (96 iterations) converges faster than alpha_2 (316 iterations)
# m=2, L=80, alpha_2 (116 iterations) converges faster than alpha_2 (364 iterations)
# m=2, L=90, alpha_2 (61 iterations) converges faster than alpha_2 (404 iterations)
# m=2, L=100, alpha_2 (195 iterations) converges faster than alpha_2 (415 iterations)
# m=3, L=10, alpha_2 (29 iterations) converges faster than alpha_2 (30 iterations)
# m=3, L=20, alpha_2 (35 iterations) converges faster than alpha_2 (61 iterations)
# m=3, L=30, alpha_2 (56 iterations) converges faster than alpha_2 (95 iterations)
# m=3, L=40, alpha_2 (53 iterations) converges faster than alpha_2 (122 iterations)
# m=3, L=50, alpha_2 (39 iterations) converges faster than alpha_2 (160 iterations)
# m=3, L=60, alpha_2 (76 iterations) converges faster than alpha_2 (187 iterations)
# m=3, L=70, alpha_2 (108 iterations) converges faster than alpha_2 (207 iterations)
# m=3, L=80, alpha_2 (96 iterations) converges faster than alpha_2 (242 iterations)
# m=3, L=90, alpha_2 (191 iterations) converges faster than alpha_2 (277 iterations)
# m=3, L=100, alpha_2 (202 iterations) converges faster than alpha_2 (321 iterations)
# m=4, L=10, alpha_2 (23 iterations) converges faster than alpha_2 (23 iterations)
# m=4, L=20, alpha_2 (27 iterations) converges faster than alpha_2 (46 iterations)
# m=4, L=30, alpha_2 (36 iterations) converges faster than alpha_2 (70 iterations)
# m=4, L=40, alpha_2 (45 iterations) converges faster than alpha_2 (93 iterations)
# m=4, L=50, alpha_2 (44 iterations) converges faster than alpha_2 (118 iterations)
# m=4, L=60, alpha_2 (62 iterations) converges faster than alpha_2 (133 iterations)
# m=4, L=70, alpha_2 (90 iterations) converges faster than alpha_2 (171 iterations)
# m=4, L=80, alpha_2 (69 iterations) converges faster than alpha_2 (176 iterations)
# m=4, L=90, alpha_2 (98 iterations) converges faster than alpha_2 (212 iterations)
# m=4, L=100, alpha_2 (63 iterations) converges faster than alpha_2 (211 iterations)
# m=5, L=10, alpha_2 (16 iterations) converges faster than alpha_2 (17 iterations)
# m=5, L=20, alpha_2 (33 iterations) converges faster than alpha_2 (37 iterations)
# m=5, L=30, alpha_2 (41 iterations) converges faster than alpha_2 (57 iterations)
# m=5, L=40, alpha_2 (42 iterations) converges faster than alpha_2 (76 iterations)
# m=5, L=50, alpha_2 (67 iterations) converges faster than alpha_2 (92 iterations)
# m=5, L=60, alpha_2 (48 iterations) converges faster than alpha_2 (111 iterations)
# m=5, L=70, alpha_2 (73 iterations) converges faster than alpha_2 (135 iterations)
# m=5, L=80, alpha_2 (54 iterations) converges faster than alpha_2 (151 iterations)
# m=5, L=90, alpha_2 (74 iterations) converges faster than alpha_2 (142 iterations)
# m=5, L=100, alpha_2 (66 iterations) converges faster than alpha_2 (188 iterations)
# m=6, L=10, alpha_2 (14 iterations) converges faster than alpha_2 (14 iterations)
# m=6, L=20, alpha_2 (21 iterations) converges faster than alpha_2 (30 iterations)
# m=6, L=30, alpha_2 (27 iterations) converges faster than alpha_2 (48 iterations)
# m=6, L=40, alpha_2 (37 iterations) converges faster than alpha_2 (60 iterations)
# m=6, L=50, alpha_2 (66 iterations) converges faster than alpha_2 (72 iterations)
# m=6, L=60, alpha_2 (22 iterations) converges faster than alpha_2 (94 iterations)
# m=6, L=70, alpha_2 (47 iterations) converges faster than alpha_2 (108 iterations)
# m=6, L=80, alpha_2 (65 iterations) converges faster than alpha_2 (125 iterations)
# m=6, L=90, alpha_2 (70 iterations) converges faster than alpha_2 (137 iterations)
# m=6, L=100, alpha_2 (75 iterations) converges faster than alpha_2 (157 iterations)
# m=7, L=10, alpha_2 (11 iterations) converges faster than alpha_2 (12 iterations)
# m=7, L=20, alpha_2 (24 iterations) converges faster than alpha_2 (26 iterations)
# m=7, L=30, alpha_2 (31 iterations) converges faster than alpha_2 (40 iterations)
# m=7, L=40, alpha_2 (32 iterations) converges faster than alpha_2 (54 iterations)
# m=7, L=50, alpha_2 (54 iterations) converges faster than alpha_2 (66 iterations)
# m=7, L=60, alpha_2 (47 iterations) converges faster than alpha_2 (82 iterations)
# m=7, L=70, alpha_2 (43 iterations) converges faster than alpha_2 (97 iterations)
# m=7, L=80, alpha_2 (48 iterations) converges faster than alpha_2 (106 iterations)
# m=7, L=90, alpha_2 (64 iterations) converges faster than alpha_2 (120 iterations)
# m=7, L=100, alpha_2 (48 iterations) converges faster than alpha_2 (116 iterations)
# m=8, L=10, alpha_2 (8 iterations) converges faster than alpha_2 (8 iterations)
# m=8, L=20, alpha_2 (19 iterations) converges faster than alpha_2 (22 iterations)
# m=8, L=30, alpha_2 (25 iterations) converges faster than alpha_2 (31 iterations)
# m=8, L=40, alpha_2 (29 iterations) converges faster than alpha_2 (45 iterations)
# m=8, L=50, alpha_2 (52 iterations) converges faster than alpha_2 (60 iterations)
# m=8, L=60, alpha_2 (41 iterations) converges faster than alpha_2 (71 iterations)
# m=8, L=70, alpha_2 (41 iterations) converges faster than alpha_2 (82 iterations)
# m=8, L=80, alpha_2 (45 iterations) converges faster than alpha_2 (91 iterations)
# m=8, L=90, alpha_2 (38 iterations) converges faster than alpha_2 (108 iterations)
# m=8, L=100, alpha_2 (88 iterations) converges faster than alpha_2 (119 iterations)
# m=9, L=10, alpha_2 (7 iterations) converges faster than alpha_2 (7 iterations)
# m=9, L=20, alpha_2 (17 iterations) converges faster than alpha_2 (19 iterations)
# m=9, L=30, alpha_2 (23 iterations) converges faster than alpha_2 (31 iterations)
# m=9, L=40, alpha_2 (26 iterations) converges faster than alpha_2 (42 iterations)
# m=9, L=50, alpha_2 (38 iterations) converges faster than alpha_2 (54 iterations)
# m=9, L=60, alpha_2 (39 iterations) converges faster than alpha_2 (57 iterations)
# m=9, L=70, alpha_2 (54 iterations) converges faster than alpha_2 (68 iterations)
# m=9, L=80, alpha_2 (56 iterations) converges faster than alpha_2 (85 iterations)
# m=9, L=90, alpha_2 (57 iterations) converges faster than alpha_2 (94 iterations)
# m=9, L=100, alpha_2 (60 iterations) converges faster than alpha_2 (102 iterations)
# m=10, L=10, alpha_2 (1 iterations) converges faster than alpha_2 (1 iterations)
# m=10, L=20, alpha_2 (17 iterations) converges faster than alpha_2 (17 iterations)
# m=10, L=30, alpha_2 (20 iterations) converges faster than alpha_2 (26 iterations)
# m=10, L=40, alpha_2 (29 iterations) converges faster than alpha_2 (38 iterations)
# m=10, L=50, alpha_2 (30 iterations) converges faster than alpha_2 (47 iterations)
# m=10, L=60, alpha_2 (42 iterations) converges faster than alpha_2 (55 iterations)
# m=10, L=70, alpha_2 (33 iterations) converges faster than alpha_2 (65 iterations)
# m=10, L=80, alpha_2 (59 iterations) converges faster than alpha_2 (75 iterations)
# m=10, L=90, alpha_2 (36 iterations) converges faster than alpha_2 (87 iterations)
# m=10, L=100, alpha_2 (78 iterations) converges faster than alpha_2 (95 iterations)

# %% [markdown]
# #### Checking conditioning
# Here, I plot the number of iterations against the condition number for both of the fixed step sizes, as well as the Wolfe step size. As we can see, the iterations for $\alpha_1$ and $\alpha_2$ grow linearly with the condition number. For the Wolfe step size, the iterations remains stable at smaller condition numbers, however, it grows more erratically as the condition number becomes larger.

# %%
iters_fixed_1 = []
iters_fixed_2 = []
iters_wolfe = []
condition_numbers = []

# Fix m
m=10 
for L in range(10, 2500, 10):
    q = 5   # Number of distinct values among the n eigenvalues
    lam = generate_lam_clustered(n, q, m, L)
    U = np.random.randn(n,n)
    U, _ = qr(U) # generate a random orthogonal matrix by performing QR decomposition on a random Gaussian matrix
    A =  A = U@np.diag(lam)@U.T
    
    # Fixed step size
    alpha_1 = 1.0 / L
    iters_fixed_1.append(gradient_descent(A, x0, alpha_1))
    alpha_2 = 2.0 / (m + L)
    iters_fixed_2.append(gradient_descent(A, x0, alpha_2))

    # Line search
    iters_wolfe.append(gradient_descent_line_search(A, x0))

    # Condition number
    condition_numbers.append(L/m)

plt.plot(condition_numbers, iters_fixed_1, label='alpha_1', color='lightblue')
plt.plot(condition_numbers, iters_fixed_2, label='alpha_2', color='purple')
plt.plot(condition_numbers, iters_wolfe, label='Wolfe Step size', color='orange')
plt.legend()
plt.ylabel('Iterations')
plt.xlabel('Condition number')
# Out:
# Text(0.5, 0, 'Condition number')

# %% [markdown]
# # Conjugate Gradient
#
# ### Converging in n-iterations
# Here, I use the minimize function from the scipy.optimize library to demonstrate the convergence of the CG method for size $n=100:1000$ in increments of 100. Clearly, the algorithm is converging much faster than $n$-iterations.

# %%
# Testing vals for n
for n in range(100, 1100, 100):
    q = 5   # Number of distinct values among the n eigenvalues
    lam = generate_lam_clustered(n, q, m, L)
    U = np.random.randn(n,n)
    U, _ = qr(U) # generate a random orthogonal matrix by performing QR decomposition on a random Gaussian matrix
    A = U@np.diag(lam)@U.T
    x0 = np.random.randn(n)

    CG_result = minimize(feval_cvx_quadratic, x0, method="CG", args=(A,), jac=grad_cvx_quadratic, tol=1e-8)
    print(f"Conjugate Gradient converged in {CG_result.nit} iterations for n={n}")
# Out:
# Conjugate Gradient converged in 6 iterations for n=100
# Conjugate Gradient converged in 5 iterations for n=200
# Conjugate Gradient converged in 5 iterations for n=300
# Conjugate Gradient converged in 5 iterations for n=400
# Conjugate Gradient converged in 5 iterations for n=500
# Conjugate Gradient converged in 5 iterations for n=600
# Conjugate Gradient converged in 6 iterations for n=700
# Conjugate Gradient converged in 6 iterations for n=800
# Conjugate Gradient converged in 6 iterations for n=900
# Conjugate Gradient converged in 6 iterations for n=1000

# %% [markdown]
# ### Convergence with q distinct eigenvalues
# I test out different values of $q$ and see how many iterations it takes for the CG method to converge. It doesn't guarantee convergence in $q$ iterations, but it **can** happen.

# %%
for q in range(5, 11, 1):
    n = 100  
    m = 10
    L = 100
    lam = generate_lam_clustered(n, q, m, L)
    U = np.random.randn(n,n)
    U, _ = qr(U) # generate a random orthogonal matrix by performing QR decomposition on a random Gaussian matrix
    A = U@np.diag(lam)@U.T
    x0 = np.random.randn(n)

    CG_result = minimize(feval_cvx_quadratic, x0, method="CG", args=(A,), jac=grad_cvx_quadratic, tol=1e-8)
    print(f"Conjugate Gradient converged in {CG_result.nit} iterations for q={q}")
# Out:
# Conjugate Gradient converged in 6 iterations for q=5
# Conjugate Gradient converged in 21 iterations for q=6
# Conjugate Gradient converged in 8 iterations for q=7
# Conjugate Gradient converged in 24 iterations for q=8
# Conjugate Gradient converged in 10 iterations for q=9
# Conjugate Gradient converged in 12 iterations for q=10

# %% [markdown]
# # Newton's and Newton-CG
#
# ### Newton's method converges in 1 iteration.
# I implement Newton's method by hand. As $n$ increases, the method still converges in 1 iteration.

# %%
# Newton's method
def newtons_method(A, x0, max_iters=10000, tol=1e-8):
    x = x0.copy()
    for i in range(max_iters):
        # Compute the gradient and Hessian
        grad_f = grad_cvx_quadratic(x, A)
        hess_f = hess_cvx_quadratic(x, A)
    
        dx = np.linalg.solve(hess_f, -grad_f)
    
        x = x + dx
        if np.linalg.norm(dx) < tol:
            break
    return x, i

# Testing for different values of n
for n in range(100, 1100, 100):
    q = 5   # Number of distinct values among the n eigenvalues
    lam = generate_lam_clustered(n, q, m, L)
    U = np.random.randn(n,n)
    U, _ = qr(U) # generate a random orthogonal matrix by performing QR decomposition on a random Gaussian matrix
    A = U@np.diag(lam)@U.T
    x0 = np.random.randn(n)

    Newton_result = newtons_method(A, x0)
    print(f"Newton's method converged in {Newton_result[1]} iterations for n={n}")
# Out:
# Newton's method converged in 1 iterations for n=100
# Newton's method converged in 1 iterations for n=200
# Newton's method converged in 1 iterations for n=300
# Newton's method converged in 1 iterations for n=400
# Newton's method converged in 1 iterations for n=500
# Newton's method converged in 1 iterations for n=600
# Newton's method converged in 1 iterations for n=700
# Newton's method converged in 1 iterations for n=800
# Newton's method converged in 1 iterations for n=900
# Newton's method converged in 1 iterations for n=1000

# %% [markdown]
# ### Comparing Newton's to Newton-CG.
# For this problem, the amount of iterations remain constant as $n$ increases. Newton's method converges in 1 iteration and Newton-CG converges in 5 iterations.

# %%
iters_newton = []
iters_newton_cg = []
n_values = []

for n in range(100, 1100, 100):
    q = 5   # Number of distinct values among the n eigenvalues
    lam = generate_lam_clustered(n, q, m, L)
    U = np.random.randn(n,n)
    U, _ = qr(U) # generate a random orthogonal matrix by performing QR decomposition on a random Gaussian matrix
    A = U@np.diag(lam)@U.T
    x0 = np.random.randn(n)

    Newton_result = newtons_method(A, x0)
    newton_CG_result = minimize(feval_cvx_quadratic, x0, method="Newton-CG", args=(A,), jac=grad_cvx_quadratic, hess=hess_cvx_quadratic, tol=1e-8)
    iters_newton.append(Newton_result[1])
    iters_newton_cg.append(CG_result.nit)
    n_values.append(n)

plt.plot(n_values, iters_newton, label="Newton's", color='lightblue')
plt.plot(n_values, iters_newton_cg, label="Newton-CG", color='orange')
plt.legend()
plt.ylabel('Iterations')
plt.xlabel('n')
# Out:
# Text(0.5, 0, 'n')

# %% [markdown]
# # BFGS and L-BFGS

# %%
iters_BFGS = []
iters_LBFGS = []
condition_numbers = []

# Fix m and iterate through large Ls
m=10 
for L in range(1000, 101000, 1000):
    q = 5   # Number of distinct values among the n eigenvalues
    lam = generate_lam_clustered(n, q, m, L)
    U = np.random.randn(n,n)
    U, _ = qr(U) # generate a random orthogonal matrix by performing QR decomposition on a random Gaussian matrix
    A =  A = U@np.diag(lam)@U.T
    
    # BFGS
    BFGS_result = minimize(feval_cvx_quadratic, x0, method="BFGS", args=(A,), jac=grad_cvx_quadratic, tol=1e-8)
    iters_BFGS.append(BFGS_result.nit)

    # L-BFGS
    L_BFGS_result = minimize(feval_cvx_quadratic, x0, method="L-BFGS-B", args=(A,), jac=grad_cvx_quadratic, tol=1e-8)
    iters_LBFGS.append(L_BFGS_result.nit)

    # Condition number
    condition_numbers.append(L/m)

plt.plot(condition_numbers, iters_BFGS, label='BFGS', color='lightblue')
plt.plot(condition_numbers, iters_LBFGS, label='L-BFGS', color='purple')
plt.legend()
plt.ylabel('Iterations')
plt.xlabel('Condition number')
# Out:
# Text(0.5, 0, 'Condition number')

# %% [markdown]
# # Comparing algorithms on the Rosenbrock function
# I chose to use the Rosenbrock function to test out the behavior of each algorithm in different dimensions. I chose this function since it is a more complex non-convex function than the quadratic and because it is often used as a benchmark function for testing algorithms. First, I define the functions I will use. The first is the gradient descent algorithm using Wolf line search to find step sizes. The second is Newton's method also with line search steps. The third is a generic function that calls scipy.optimize.minimize for CG, Newton-CG, BFGS, and L-BFGS.

# %%
# MODIFIED GD AND NEWTON ALGORITHMS

# GRAD DESCENT WITH WOLFE LINE SEARCH
def gradient_descent_line_search(x0, max_iters=10000, tol=1e-8):
    x = x0.copy()
    f_vals = []
    grad_norms = []
    
    for i in range(max_iters):
        f_val = rosen(x)
        grad = rosen_der(x)
        
        f_vals.append(f_val)
        grad_norms.append(np.linalg.norm(grad))

        if np.linalg.norm(grad) < tol:
            break
        
        ls = line_search(lambda z: rosen(z),
                         lambda z: rosen_der(z),
                         x, -grad)
        alpha = ls[0]
        if alpha is None:
            alpha = 1e-3
        
        x = x - alpha * grad
    
    return x, np.array(f_vals), np.array(grad_norms)

# NEWTON"S METHOD
def newtons_method(x0, max_iters=10000, tol=1e-8):
    x = x0.copy()
    f_vals = []
    grad_norms = []
    
    for i in range(max_iters):
        # Evaluate the function, gradient, and Hessian
        f_val = rosen(x)
        grad = rosen_der(x)
        hess = rosen_hess(x)
        
        f_vals.append(f_val)
        grad_norms.append(np.linalg.norm(grad))
        
        # Check convergence by gradient norm
        if np.linalg.norm(grad) < tol:
            break
        
        # Compute the "pure" Newton step
        dx = -np.linalg.solve(hess, grad)
        
        # Perform a line search to find an appropriate step size
        alpha = line_search(rosen, rosen_der, x, dx)[0]
        
        # If line_search fails (returns None), revert to a small fallback step
        if alpha is None:
            alpha = 1e-3
        
        # Update x
        x = x + alpha * dx
        
        # Optionally also check the step size itself for convergence
        if np.linalg.norm(alpha * dx) < tol:
            break
    
    return x, np.array(f_vals), np.array(grad_norms)

# GENERAL FUNCTION TO RUN SCIPY MINIMIZE
def scipy_minimize(method, x0, max_iters=10000, tol=1e-8):
    f_vals = []
    grad_vals = []
    
    def store_iter(xk):
        f_vals.append(rosen(xk))
        grad_vals.append(np.linalg.norm(rosen_der(xk)))
        
    min_f = minimize(fun=rosen, x0=x0, jac=rosen_der, hess=rosen_hess, method=method, callback=store_iter, options={'maxiter':max_iters})
    
    if not f_vals or f_vals[-1] != rosen(min_f.x):
        f_vals.append(rosen(min_f.x))
        grad_vals.append(np.linalg.norm(rosen_der(min_f.x)))
    
    return min_f.x, np.array(f_vals), np.array(grad_vals)

# %% [markdown]
# ### Interpreting Charts
# In this cell, I produce a subplot of the function values and gradient norms of each algorithm on a $\log_{10}$ scale for different dimensions ($n=100,200,300,400,500$). As the dimension increases, the behavior of each algorithm behaves differently:
#
# **Gradient descent with line search:** In higher dimensions, the gradient descent algorithm with line search is very slow in converging to the optimal solution. This could be due to the non-convex geometry of the function, since gradient descent is often used for convex problems.
#
# **Newton's Method with Line Search:** Newton's method performs well in lower dimensions (n=100,200 for this case), but like GD with line search, it struggles to converge as we move into higher dimensions. The oscillation in higher dimensions suggests that the method is "overshooting" and fails to converge. This is likely due to the Rosenbrock Hessian being ill-conditioned, as Newton's method is dependent upon second-order information.
#
# **CG Method:** In all of the given dimensions, the CG method seems to rapidly approach the solution, before stabilizing and slowly descending, and then rapidly approaching the solution again until it converges. Compared to Newton's method and GD, the method is able to converge to the solution in high dimensions, though relatively slow to other methods.
#
# **Newton-CG:** The Newton-CG method behaves similarly to the CG method, except that it is a little less stable in descending and has more sharp decreases toward the objective optimum. The increased instability could be due to the ill-conditioning of the Rosenbrock Hessian, since Newton-CG is a Quasi-Newton method that uses second-order information. However, a big thing to note that Newton-CG converges much faster than CG in several orders of magnitude.
#
# **BFGS:** The BFGS method seems to slowly converge toward the optimum for the majority of the iterations before rapidly descending. The interesting thing to note is that in smaller dimensions of the Rosenbrock Function, BFGS converges much slower than algorithms like Newton's method or CG. However, as n increases, then the BFGS seems to increase in amount of iterations linearly, while CG and Newton's grow much larger and fail to converge at all, respectively. BFGS is better than these methods for the Rosenbrock function in high dimensions.
#
# **L-BFGS:** Even in moderately high dimensions, like n=500, the L-BFGS method converges slower than the BFGS method. This is because the BFGS method does not discard past information of the Hessian approximation, which is where the limited memory capacity of the Limited Memory BFGS comes from. For problems where n is very large, L-BFGS is a more suitable algorithm, as the computational cost of memory storage may be too much for BFGS to handle.

# %%
# Setup
for n in range(100, 600, 100):
    x = np.linspace(-1, 1, n)
    x0 = np.random.randn(n)

    #Grad Descent with Wolfe Line Search
    gd_x, gd_obj, gd_grad = gradient_descent_line_search(x0)
    # Newton's Method
    nm_x, nm_obj, nm_grad = newtons_method(x0)
    # CG
    cg_x, cg_obj, cg_grad = scipy_minimize('CG', x0)
    # Newton-CG
    ncg_x, ncg_obj, ncg_grad = scipy_minimize('Newton-CG', x0)
    # BFGS
    bfgs_x, bfgs_obj, bfgs_grad = scipy_minimize('BFGS', x0)
    # L-BFGS
    lbfgs_x, lbfgs_obj, lbfgs_grad = scipy_minimize('L-BFGS-B', x0)

    # Methods to be passed to minimize function
    methods = [
        ("GD + line search", gd_obj, gd_grad),
        ("Newton's Method", nm_obj, nm_grad),
        ("CG", cg_obj, cg_grad),
        ("Newton-CG", ncg_obj, ncg_grad),
        ("BFGS", bfgs_obj, bfgs_grad),
        ("L-BFGS-B", lbfgs_obj, lbfgs_grad)
    ]

    fig, axes = plt.subplots(nrows=6, ncols=2, figsize=(12, 20))

    for i, (method_name, obj_vals, grad_vals) in enumerate(methods):
        # Left subplot: Objective
        axes[i, 0].plot(np.log10(obj_vals), color="lightblue")
        axes[i, 0].set_title(f"Objective (log10 scale) for {method_name} for n={n}")
        axes[i, 0].set_xlabel("Iteration")
        axes[i, 0].set_ylabel("Function Val (log10 scale)")
        
        # Right subplot: Gradient norm
        axes[i, 1].plot(np.log10(grad_vals), color="orange")
        axes[i, 1].set_title(f"Gradient Norm (log10 scale) for {method_name} for n={n}")
        axes[i, 1].set_xlabel("Iteration")
        axes[i, 1].set_ylabel("Grad Norm (log10 scale)")

    plt.tight_layout()
    plt.show()
