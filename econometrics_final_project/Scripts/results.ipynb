# %%
import json

with open('/Users/jayco/Desktop/EBGN590/Final-Project/Data/models.json', 'r') as f:
    models_data = json.load(f)

# %%
#Coal
print("Regressor:", models_data['Regressor'][0])
print("Summary:\n", models_data['Summary'][0])
print("PC Relations:\n", models_data['PC_relationships'][0])
# Out:
# Regressor: ppi_coal
# Summary:
#                              OLS Regression Results
# ...
# Dep. Variable:           energy_index   R-squared:                       0.895
# Model:                            OLS   Adj. R-squared:                  0.893
# Method:                 Least Squares   F-statistic:                     603.8
# Date:                Mon, 15 Apr 2024   Prob (F-statistic):          2.04e-171
# Time:                        18:35:18   Log-Likelihood:                -1448.6
# No. Observations:                 362   AIC:                             2909.
# Df Residuals:                     356   BIC:                             2932.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        131.4360      0.701    187.422      0.000     130.057     132.815
# ...

# %%
#Crude
print("Regressor:", models_data['Regressor'][1])
print("Summary:\n", models_data['Summary'][1])
print("PC Relations:\n", models_data['PC_relationships'][1])
# Out:
# Regressor: ppi_crude
# Summary:
#                              OLS Regression Results
# ...
# Dep. Variable:           energy_index   R-squared:                       0.876
# Model:                            OLS   Adj. R-squared:                  0.874
# Method:                 Least Squares   F-statistic:                     503.4
# Date:                Fri, 12 Apr 2024   Prob (F-statistic):          5.61e-159
# Time:                        15:58:46   Log-Likelihood:                -1477.7
# No. Observations:                 362   AIC:                             2967.
# Df Residuals:                     356   BIC:                             2991.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        131.4360      0.760    172.919      0.000     129.941     132.931
# ...

# %%
#Natural Gas
print("Regressor:", models_data['Regressor'][2])
print("Summary:\n", models_data['Summary'][2])
print("PC Relations:\n", models_data['PC_relationships'][2])
# Out:
# Regressor: ppi_nat_gas
# Summary:
#                              OLS Regression Results
# ...
# Dep. Variable:           energy_index   R-squared:                       0.556
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     89.16
# Date:                Fri, 12 Apr 2024   Prob (F-statistic):           1.29e-60
# Time:                        15:58:46   Log-Likelihood:                -1708.7
# No. Observations:                 362   AIC:                             3429.
# Df Residuals:                     356   BIC:                             3453.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        131.4360      1.439     91.352      0.000     128.606     134.266
# ...

# %%
#Gasoline
print("Regressor:", models_data['Regressor'][3])
print("Summary:\n", models_data['Summary'][3])
print("PC Relations:\n", models_data['PC_relationships'][3])
# Out:
# Regressor: ppi_gasoline
# Summary:
#                              OLS Regression Results
# ...
# Dep. Variable:           energy_index   R-squared:                       0.910
# Model:                            OLS   Adj. R-squared:                  0.909
# Method:                 Least Squares   F-statistic:                     719.7
# Date:                Fri, 12 Apr 2024   Prob (F-statistic):          1.18e-183
# Time:                        15:58:46   Log-Likelihood:                -1419.9
# No. Observations:                 362   AIC:                             2852.
# Df Residuals:                     356   BIC:                             2875.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        131.4360      0.648    202.875      0.000     130.162     132.710
# ...

# %%
#Diesel
print("Regressor:", models_data['Regressor'][4])
print("Summary:\n", models_data['Summary'][4])
print("PC Relations:\n", models_data['PC_relationships'][4])
# Out:
# Regressor: ppi_diesel
# Summary:
#                              OLS Regression Results
# ...
# Dep. Variable:           energy_index   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.928
# Method:                 Least Squares   F-statistic:                     925.4
# Date:                Fri, 12 Apr 2024   Prob (F-statistic):          1.64e-201
# Time:                        15:58:46   Log-Likelihood:                -1378.0
# No. Observations:                 362   AIC:                             2768.
# Df Residuals:                     356   BIC:                             2791.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        131.4360      0.577    227.733      0.000     130.301     132.571
# ...

# %%
#Heating oil
print("Regressor:", models_data['Regressor'][5])
print("Summary:\n", models_data['Summary'][5])
print("PC Relations:\n", models_data['PC_relationships'][5])
# Out:
# Regressor: ppi_heat_oil
# Summary:
#                              OLS Regression Results
# ...
# Dep. Variable:           energy_index   R-squared:                       0.914
# Model:                            OLS   Adj. R-squared:                  0.913
# Method:                 Least Squares   F-statistic:                     758.8
# Date:                Fri, 12 Apr 2024   Prob (F-statistic):          2.19e-187
# Time:                        15:58:46   Log-Likelihood:                -1411.1
# No. Observations:                 362   AIC:                             2834.
# Df Residuals:                     356   BIC:                             2858.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        131.4360      0.632    207.835      0.000     130.192     132.680
# ...

# %%
print("Regressor:", models_data['Regressor'][6])
print("Summary:\n", models_data['Summary'][6])
print("PC Relations:\n", models_data['PC_relationships'][6])
# Out:
# Regressor: total
# Summary:
#                              OLS Regression Results
# ...
# Dep. Variable:           energy_index   R-squared:                       0.959
# Model:                            OLS   Adj. R-squared:                  0.958
# Method:                 Least Squares   F-statistic:                     1658.
# Date:                Fri, 12 Apr 2024   Prob (F-statistic):          4.46e-244
# Time:                        16:33:34   Log-Likelihood:                -1278.3
# No. Observations:                 362   AIC:                             2569.
# Df Residuals:                     356   BIC:                             2592.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        131.4360      0.438    299.952      0.000     130.574     132.298
# ...
